# %%
import os
import pandas as pd
import openpyxl
from groq import Groq

groq_api_key = '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'
client = Groq(api_key=groq_api_key)
data = pd.read_excel("./data/client_fact_table.xlsx", sheet_name='Sheet1')

# Convert the DataFrame to a string
cells_content = []
for index, row in data.iterrows():
    row_content = ", ".join([f"{col}: {row[col]}" for col in data.columns])
    cells_content.append(row_content)
    
all_content = "\n".join(cells_content)
data_str=all_content

# %%
f"{input_text}\nHere is the relevant transaction data:\n{data_str}"

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "you are a helpful assistant and expert in asset management industry. You write short answers."
        },
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama3-8b-8192",
)

print(chat_completion.choices[0].message.content)
