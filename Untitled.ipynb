# %%
import pandas as pd
import os
from dotenv import load_dotenv
from pandasai import SmartDataframe
from langchain_groq.chat_models import ChatGroq

# %%
client_demographics_df = pd.read_csv('data/client_demographics.csv')
transactions_df = pd.read_csv('data/client_transactions.csv')

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model_name = 'llama3-70b-8192',api_key = os.environ['GROQ_API_KEY'])

# %%
from pandasai import SmartDatalake

# %%
lake = SmartDatalake([client_demographics_df, transactions_df], config={"llm": llm})

# %%
lake.chat("what was the biggest transaction during the period?")
# Out:
# 'The biggest transaction during the period was Epsilon Inc. 2026 Term Loan B,  L+300 with a total value of $176,102,190.00.'
