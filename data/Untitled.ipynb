# %%
import os
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet
import base64
import random
from groq import Groq
import plotly.graph_objects as go

# %%
trans = pd.read_csv('client_transactions.csv')
# Filter for 'selected_strategy' equal to 'Private Equity'
filtered_trans = trans[trans['Select_Strategy'] == 'Private Equity']
transactions_df=trans
# Display the filtered DataFrame
print(filtered_trans)
# Out:
#      Date                                               Name Select_Strategy  \
# 75  44484                          Acme Co. 2023 Term Loan B  Private Equity
# 76  42136                 XYZ Corp. 2024 Mezzanine Financing  Private Equity
# 77  42797                  RetailCo Distressed Debt Position  Private Equity
# 78  44169                   TechCo Recapitalization Facility  Private Equity
# 79  43507               Alpha Industries Senior Secured Loan  Private Equity
# 80  45361          Beta Pharmaceuticals Unitranche Financing  Private Equity
# 81  44762                   Gamma Real Estate Mezzanine Debt  Private Equity
# 82  42160                  Delta Energy Project Finance Loan  Private Equity
# 83  43910                Epsilon Healthcare Second Lien Loan  Private Equity
# 84  42190           Zeta Manufacturing Acquisition Financing  Private Equity
# 85  44130           Eta Technology Growth Capital Investment  Private Equity
# ...

# %%
filtered_transactions = transactions_df[transactions_df['Select_Strategy'] == 'Private Equity']
top_buys = filtered_transactions[filtered_transactions['Transaction Type'] == 'Buy'].nlargest(1, 'Total Value ($)')
top_sells = filtered_transactions[filtered_transactions['Transaction Type'] == 'Sell'].nlargest(1, 'Total Value ($)')
# top_transactions = pd.concat([top_buys, top_sells])
# top_transactions_df = top_transactions[['Name', 'Direction', 'Transaction Type', 'Commentary']]
# top_transactions_df

# %%
filtered_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 75 to 89
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 15 non-null     int64
#  1   Name                 15 non-null     object
#  2   Select_Strategy      15 non-null     object
#  3   Direction            15 non-null     object
#  4   Quantity             15 non-null     int64
#  5   Price per Share ($)  15 non-null     int64
#  6   Total Value ($)      15 non-null     int64
#  7   Transaction Type     15 non-null     object
#  8   Commentary           15 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 1.2+ KB

# %%
# Assuming transactions_df is correctly loaded and filtered as needed
# Ensure the column types are correct, especially Total Value ($) should be numeric
transactions_df['Total Value ($)'] = pd.to_numeric(transactions_df['Total Value ($)'])

# Check the dtype of 'Total Value ($)'
print(transactions_df['Total Value ($)'].dtype)

# Reset index after filtering if necessary
filtered_transactions = filtered_transactions.reset_index(drop=True)

# Filter top buy transaction
top_buys = filtered_transactions[filtered_transactions['Transaction Type'] == 'Buy'].nlargest(1, 'Total Value ($)')

# Filter top sell transaction
top_sells = filtered_transactions[filtered_transactions['Transaction Type'] == 'Sell'].nlargest(1, 'Total Value ($)')

print("Top Buy Transaction:")
print(top_buys)

print("\nTop Sell Transaction:")
print(top_sells)
# Out:
# int64
# Top Buy Transaction:
# Empty DataFrame
# Columns: [Date, Name, Select_Strategy, Direction, Quantity, Price per Share ($), Total Value ($), Transaction Type, Commentary]
# Index: []
#
# Top Sell Transaction:
# Empty DataFrame
# Columns: [Date, Name, Select_Strategy, Direction, Quantity, Price per Share ($), Total Value ($), Transaction Type, Commentary]
# Index: []

# %%
top_buys
# Out:
# Empty DataFrame
# Columns: [Date, Name, Select_Strategy, Direction, Quantity, Price per Share ($), Total Value ($), Transaction Type, Commentary]
# Index: []

# %%
top_sells = filtered_transactions[filtered_transactions.iloc[:, 7] == 'Sell'].nlargest(1, columns=filtered_transactions.columns[6])

# %%
top_sells
# Out:
# Empty DataFrame
# Columns: [Date, Name, Select_Strategy, Direction, Quantity, Price per Share ($), Total Value ($), Transaction Type, Commentary]
# Index: []
