# %%
import pandas as pd

# Sample data for different asset classes
data = {
    'Date': [
        '2023-07-14', '2023-07-14', '2023-07-14'
        # , '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14',
        # '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14',
        # '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14',
        # '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14',
        # '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14',
        # '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14', '2023-07-14'
    ],
    'Client ID': [
        1, 1, 1
    ],
    'Ticker': [
        'AAPL US', 'MSFT US', 'AMZN US'
    ],
    'Quantity': [
        100, 100, 100
    ],
    'Price per Share ($)': [
        150.50, 150.50, 150.50
    ],
    'Total Value ($)': [
        15050.00, 15050.00, 15050.00
    ],
    'Transaction Type': [
        'Buy', 'Buy', 'Buy'
        , 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy',
        'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Sell', 'Sell', 'Sell', 'Sell', 'Sell',
        'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy',
        'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy',
        'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy',
        'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy', 'Buy'
    ],
    'Commentary': [
        'Strong Q2 earnings with high consumer demand', 'Increased cloud market share', 'Expansion in new service sectors'
        'Successful market penetration in Europe', 'Innovations in hybrid vehicles enhance market position',
        'Consistent dividend yield attracts investors', 'Drug pipeline progress sparks interest', 'Biotech R&D leads to breakthrough',
        'Industrial demand boosts share prices', 'Sustainable products drive market gain', 'Software solutions lead to customer growth',
        'Industrial automation trends upwards', 'Telecom sector regains strength', 'Auto industry recovery post-pandemic',
        'Electric vehicle initiative pushes stock up', 'Short sell due to speculative trading surge', 'Market volatility impacts stock',
        'Outdated tech drags company down', 'Retail challenges lead to stock decline', 'Financial mismanagement impacts stock',
        'Loan facilitates new product line', 'Industrial expansion supported by loan', 'Energy sector financing', 'Healthcare innovations funded',
        'Tech advancements drive growth', 'Media expansion into streaming', 'Hospitality industry recovery', 'Transport logistics optimization',
        'Pharmaceutical R&D expansion', 'Infrastructure development funding', 'Strong government bond market', 'Gilt offers stable returns',
        'Bund demand increases with economic stability', 'Investor confidence in JGBs', 'Long-term stability from Canadian bonds',
        'Australian bond yields appeal', 'Belgian bonds offer diversification', 'French bond market stability', 'Italian bonds for yield',
        'Spanish bonds and economic recovery', 'Muni bond funds essential city projects', 'State bonds fund infrastructure',
        'Municipal funding supports public services', 'Muni bonds for public projects', 'City bonds support urban development',
        'Municipal investment in public infrastructure', 'City development bonds', 'Urban renewal projects funded', 'Long-term corporate debt investment',
        'Tech growth supports corporate bond', 'Corporate debt reflects solid fundamentals', 'Financial sector stability',
        'Energy sector debt reflects solid yield', 'Banking industry bonds offer security', 'Corporate debt supports industrial growth'
    ],
    'Asset Type': [
        'Equity', 'Equity', 'Equity'
        # 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity',
        # 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity', 'Equity',
        # 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan',
        # 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan', 'Leveraged Loan',
        # 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond',
        # 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond', 'Corporate Bond'
    ]
}

# Create DataFrame
df_transactions = pd.DataFrame(data)

# Display DataFrame
print(df_transactions)
# Out:
#          Date  Client ID   Ticker  Quantity  Price per Share ($)  \
# 0  2023-07-14          1  AAPL US       100                150.5
# 1  2023-07-14          1  MSFT US       100                150.5
# 2  2023-07-14          1  AMZN US       100                150.5
#
#    Total Value ($) Transaction Type  \
# 0          15050.0              Buy
# 1          15050.0              Buy
# 2          15050.0              Buy
#
#                                      Commentary Asset Type
# 0  Strong Q2 earnings with high consumer demand     Equity
# 1                  Increased cloud market share     Equity
# 2              Expansion in new service sectors     Equity
